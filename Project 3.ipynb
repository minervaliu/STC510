# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
customers = pd.read_csv('crimestat (1).csv')
customers.head
# Out:
# /var/folders/9n/qnh7vnj50mb9p3j36q9cp78h0000gn/T/ipykernel_17095/2638251669.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   customers = pd.read_csv('crimestat (1).csv')
# <bound method NDFrame.head of                INC NUMBER    OCCURRED ON    OCCURRED TO   UCR CRIME CATEGORY  \
# 0               2.016E+14   11/1/15 0:00    1/9/16 0:00  MOTOR VEHICLE THEFT
# 1               2.016E+14   11/1/15 0:00            NaN                 RAPE
# 2               2.015E+14   11/1/15 0:00   11/1/15 9:00        LARCENY-THEFT
# 3               2.015E+14   11/1/15 0:00   11/1/15 5:00  MOTOR VEHICLE THEFT
# 4               2.015E+14   11/1/15 0:00  11/1/15 11:50  MOTOR VEHICLE THEFT
# ...                   ...            ...            ...                  ...
# 131671  201700000000000.0  11/17/17 4:00  11/17/17 4:06             BURGLARY
# 131672  201700000000000.0  11/17/17 4:15  11/17/17 4:30        LARCENY-THEFT
# ...

# %%
customers.sort_index(inplace=True)
customers.head()
# Out:
#   INC NUMBER   OCCURRED ON    OCCURRED TO   UCR CRIME CATEGORY  \
# 0  2.016E+14  11/1/15 0:00    1/9/16 0:00  MOTOR VEHICLE THEFT
# 1  2.016E+14  11/1/15 0:00            NaN                 RAPE
# 2  2.015E+14  11/1/15 0:00   11/1/15 9:00        LARCENY-THEFT
# 3  2.015E+14  11/1/15 0:00   11/1/15 5:00  MOTOR VEHICLE THEFT
# 4  2.015E+14  11/1/15 0:00  11/1/15 11:50  MOTOR VEHICLE THEFT
#
#              100 BLOCK ADDR      ZIP         PREMISE TYPE
# 0  N 43RD AVE & W CACTUS RD  85029.0  SINGLE FAMILY HOUSE
# 1         13XX E ALMERIA RD  85006.0  SINGLE FAMILY HOUSE
# 2            51XX N 15TH ST  85014.0            APARTMENT
# 3       102XX W MEDLOCK AVE  85307.0  SINGLE FAMILY HOUSE
# 4            69XX W WOOD ST  85043.0  SINGLE FAMILY HOUSE

# %%
zip = customers.ZIP
zip
# Out:
# 0         85029.0
# 1         85006.0
# 2         85014.0
# 3         85307.0
# 4         85043.0
#            ...
# 131671    85040.0
# 131672    85016.0
# 131673    85037.0
# 131674    85043.0
# 131675    85019.0
# Name: ZIP, Length: 131676, dtype: float64

# %%
zip_area1 = customers[(customers.ZIP<85099)] # group crimes by zip codes
zip_area1
# Out:
#                INC NUMBER    OCCURRED ON    OCCURRED TO   UCR CRIME CATEGORY  \
# 0               2.016E+14   11/1/15 0:00    1/9/16 0:00  MOTOR VEHICLE THEFT
# 1               2.016E+14   11/1/15 0:00            NaN                 RAPE
# 2               2.015E+14   11/1/15 0:00   11/1/15 9:00        LARCENY-THEFT
# 4               2.015E+14   11/1/15 0:00  11/1/15 11:50  MOTOR VEHICLE THEFT
# 5               2.016E+14   11/1/15 0:00   3/22/16 0:36        LARCENY-THEFT
# ...                   ...            ...            ...                  ...
# 131671  201700000000000.0  11/17/17 4:00  11/17/17 4:06             BURGLARY
# 131672  201700000000000.0  11/17/17 4:15  11/17/17 4:30        LARCENY-THEFT
# 131673  201700000000000.0  11/17/17 5:00  11/17/17 9:50  MOTOR VEHICLE THEFT
# 131674  201700000000000.0  11/17/17 5:34            NaN   AGGRAVATED ASSAULT
# 131675  201700000000000.0  11/17/17 5:50  11/17/17 7:50             BURGLARY
#
# ...

# %%
zip_area2 = customers[(customers.ZIP <85199)& (customers.ZIP > 85099)] # group crimes by zip codes
zip_area2
# Out:
# Empty DataFrame
# Columns: [INC NUMBER, OCCURRED ON, OCCURRED TO, UCR CRIME CATEGORY, 100 BLOCK ADDR, ZIP, PREMISE TYPE]
# Index: []

# %%
zip_area3 = customers[(customers.ZIP <85299)& (customers.ZIP > 85199)] # group crimes by zip codes
zip_area3
# Out:
#                INC NUMBER     OCCURRED ON     OCCURRED TO  \
# 19              2.016E+14    11/1/15 0:01    1/7/16 12:00
# 65              2.015E+14   11/1/15 10:08   11/1/15 10:08
# 67              2.015E+14   11/1/15 11:35             NaN
# 156             2.015E+14   11/1/15 22:45    11/2/15 7:30
# 248             2.015E+14   11/2/15 14:37   11/2/15 14:38
# ...                   ...             ...             ...
# 131543  201700000000000.0  11/16/17 14:00  11/18/17 12:23
# 131638  201700000000000.0  11/16/17 23:00   11/17/17 8:00
# 131639     201780000000.0  11/16/17 23:00   11/17/17 6:00
# 131654     201780000000.0   11/17/17 0:00   11/17/17 6:30
# 131669  201700000000000.0   11/17/17 3:17             NaN
#
#          UCR CRIME CATEGORY          100 BLOCK ADDR      ZIP  \
# 19      MOTOR VEHICLE THEFT  48XX E DESERT COVE AVE  85254.0
# 65            LARCENY-THEFT      168XX N TATUM BLVD  85254.0
# 67            LARCENY-THEFT   136XX N SCOTTSDALE RD  85254.0
# ...

# %%
zip_area4 = customers[(customers.ZIP <85399)& (customers.ZIP > 85299)] # group crimes by zip codes
zip_area4
# Out:
#                INC NUMBER     OCCURRED ON     OCCURRED TO  \
# 3               2.015E+14    11/1/15 0:00    11/1/15 5:00
# 13              2.016E+14    11/1/15 0:01   3/28/16 17:20
# 33              2.015E+14    11/1/15 2:00   11/1/15 14:20
# 42              2.015E+14    11/1/15 5:38    11/1/15 9:35
# 58             2.0158E+11    11/1/15 9:14   11/27/15 9:15
# ...                   ...             ...             ...
# 131522     201880000000.0  11/16/17 10:45  11/16/17 11:30
# 131565  201700000000000.0  11/16/17 15:50             NaN
# 131566  201700000000000.0  11/16/17 16:00  11/16/17 16:06
# 131573  201700000000000.0  11/16/17 16:40  11/16/17 16:41
# 131584  201700000000000.0  11/16/17 17:45  11/16/17 21:00
#
#          UCR CRIME CATEGORY       100 BLOCK ADDR      ZIP  \
# 3       MOTOR VEHICLE THEFT  102XX W MEDLOCK AVE  85307.0
# 13            LARCENY-THEFT    46XX W FREMONT RD  85339.0
# 33      MOTOR VEHICLE THEFT      85XX W MIAMI ST  85353.0
# ...

# %%
n.sort_values(by=['UCR CRIME CATEGORY', 'PREMISE TYPE'],ascending=[True,False])
# Out:
#                INC NUMBER     OCCURRED ON   OCCURRED TO  UCR CRIME CATEGORY  \
# 7443            2.015E+14   12/16/15 2:41           NaN  AGGRAVATED ASSAULT
# 27874           2.016E+14    4/15/16 0:19           NaN  AGGRAVATED ASSAULT
# 37638           2.016E+14   6/10/16 17:15  6/13/16 9:20  AGGRAVATED ASSAULT
# 38975           2.016E+14    6/18/16 9:53  6/18/16 9:53  AGGRAVATED ASSAULT
# 96237           2.017E+14    5/8/17 10:00           NaN  AGGRAVATED ASSAULT
# ...                   ...             ...           ...                 ...
# 79880           2.017E+14    2/4/17 20:15  2/4/17 20:19             ROBBERY
# 101393          2.017E+14    6/4/17 21:40           NaN             ROBBERY
# 114647          2.017E+14    8/16/17 3:43  8/16/17 3:43             ROBBERY
# 126844          2.017E+14  10/21/17 21:45           NaN             ROBBERY
# 131436  201700000000000.0  11/15/17 20:00           NaN             ROBBERY
#
# ...

# %%
npub = n.groupby(['UCR CRIME CATEGORY'])
type(npub)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
npub.get_group('AGGRAVATED ASSAULT')
# Out:
#                INC NUMBER     OCCURRED ON     OCCURRED TO  UCR CRIME CATEGORY  \
# 30             2.0151E+14    11/1/15 2:00    11/1/15 6:00  AGGRAVATED ASSAULT
# 32              2.015E+14    11/1/15 2:00   11/1/15 12:00  AGGRAVATED ASSAULT
# 45              2.015E+14    11/1/15 6:10    11/1/15 6:22  AGGRAVATED ASSAULT
# 79              2.015E+14   11/1/15 12:02   11/1/15 12:02  AGGRAVATED ASSAULT
# 82              2.015E+14   11/1/15 13:00   11/1/15 13:30  AGGRAVATED ASSAULT
# ...                   ...             ...             ...                 ...
# 131623  201700000000000.0  11/16/17 21:10  11/16/17 21:10  AGGRAVATED ASSAULT
# 131646  201700000000000.0  11/16/17 23:50  11/16/17 23:57  AGGRAVATED ASSAULT
# 131651  201700000000000.0   11/17/17 0:00   11/17/17 0:00  AGGRAVATED ASSAULT
# 131667  201700000000000.0   11/17/17 3:00   11/17/17 3:20  AGGRAVATED ASSAULT
# 131674  201700000000000.0   11/17/17 5:34             NaN  AGGRAVATED ASSAULT
#
# ...

# %%
npub.get_group('BURGLARY')
# Out:
#                INC NUMBER    OCCURRED ON     OCCURRED TO UCR CRIME CATEGORY  \
# 18              2.016E+14   11/1/15 0:01   1/30/16 23:59           BURGLARY
# 21              2.015E+14   11/1/15 0:01    12/6/15 9:45           BURGLARY
# 23              2.015E+14   11/1/15 0:01    11/1/15 3:55           BURGLARY
# 34              2.015E+14   11/1/15 2:38    11/1/15 3:05           BURGLARY
# 40              2.015E+14   11/1/15 4:25             NaN           BURGLARY
# ...                   ...            ...             ...                ...
# 131652  201700000000000.0  11/17/17 0:00  11/24/17 12:02           BURGLARY
# 131655  201700000000000.0  11/17/17 0:01   11/18/17 8:00           BURGLARY
# 131666  201700000000000.0  11/17/17 2:48   11/17/17 2:48           BURGLARY
# 131671  201700000000000.0  11/17/17 4:00   11/17/17 4:06           BURGLARY
# 131675  201700000000000.0  11/17/17 5:50   11/17/17 7:50           BURGLARY
#
# ...

# %%
npub.get_group('ROBBERY')
# Out:
#                INC NUMBER     OCCURRED ON     OCCURRED TO UCR CRIME CATEGORY  \
# 39              2.015E+14    11/1/15 4:14             NaN            ROBBERY
# 89              2.015E+14   11/1/15 13:33   11/1/15 13:35            ROBBERY
# 123             2.015E+14   11/1/15 17:00   11/1/15 17:30            ROBBERY
# 149             2.015E+14   11/1/15 21:00   11/1/15 21:10            ROBBERY
# 152             2.015E+14   11/1/15 21:15             NaN            ROBBERY
# ...                   ...             ...             ...                ...
# 131618  201700000000000.0  11/16/17 20:30             NaN            ROBBERY
# 131627  201700000000000.0  11/16/17 21:54             NaN            ROBBERY
# 131634  201700000000000.0  11/16/17 22:30             NaN            ROBBERY
# 131647  201700000000000.0  11/16/17 23:50  11/16/17 23:50            ROBBERY
# 131665  201700000000000.0   11/17/17 2:35   11/17/17 2:35            ROBBERY
#
# ...

# %%
npub.get_group('MOTOR VEHICLE THEFT')
# Out:
#                INC NUMBER     OCCURRED ON     OCCURRED TO  \
# 0               2.016E+14    11/1/15 0:00     1/9/16 0:00
# 3               2.015E+14    11/1/15 0:00    11/1/15 5:00
# 4               2.015E+14    11/1/15 0:00   11/1/15 11:50
# 14              2.015E+14    11/1/15 0:01   11/30/15 0:00
# 19              2.016E+14    11/1/15 0:01    1/7/16 12:00
# ...                   ...             ...             ...
# 131640  201700000000000.0  11/16/17 23:00  11/16/17 23:45
# 131641  201700000000000.0  11/16/17 23:00   11/17/17 5:30
# 131656  201700000000000.0   11/17/17 0:01   11/17/17 7:10
# 131660  201700000000000.0   11/17/17 1:00   11/17/17 6:00
# 131673  201700000000000.0   11/17/17 5:00   11/17/17 9:50
#
#          UCR CRIME CATEGORY            100 BLOCK ADDR      ZIP  \
# 0       MOTOR VEHICLE THEFT  N 43RD AVE & W CACTUS RD  85029.0
# 3       MOTOR VEHICLE THEFT       102XX W MEDLOCK AVE  85307.0
# 4       MOTOR VEHICLE THEFT            69XX W WOOD ST  85043.0
# ...

# %%
npub.get_group('LARCENY-THEFT')
# Out:
#                INC NUMBER    OCCURRED ON    OCCURRED TO UCR CRIME CATEGORY  \
# 2               2.015E+14   11/1/15 0:00   11/1/15 9:00      LARCENY-THEFT
# 5               2.016E+14   11/1/15 0:00   3/22/16 0:36      LARCENY-THEFT
# 6               2.017E+14   11/1/15 0:00            NaN      LARCENY-THEFT
# 8               2.015E+14   11/1/15 0:00  11/11/15 9:30      LARCENY-THEFT
# 10              2.016E+14   11/1/15 0:01   3/27/16 8:00      LARCENY-THEFT
# ...                   ...            ...            ...                ...
# 131663  201700000000000.0  11/17/17 2:16            NaN      LARCENY-THEFT
# 131664  201700000000000.0  11/17/17 2:35  11/17/17 2:45      LARCENY-THEFT
# 131668     201780000000.0  11/17/17 3:13  11/17/17 3:20      LARCENY-THEFT
# 131669  201700000000000.0  11/17/17 3:17            NaN      LARCENY-THEFT
# 131672  201700000000000.0  11/17/17 4:15  11/17/17 4:30      LARCENY-THEFT
#
# ...

# %%
npub.get_group('RAPE')
# Out:
#                INC NUMBER     OCCURRED ON     OCCURRED TO UCR CRIME CATEGORY  \
# 1               2.016E+14    11/1/15 0:00             NaN               RAPE
# 7               2.017E+14    11/1/15 0:00    3/31/16 0:00               RAPE
# 37              2.015E+14    11/1/15 4:00    11/1/15 4:05               RAPE
# 56              2.015E+14    11/1/15 9:00             NaN               RAPE
# 63              2.016E+14   11/1/15 10:00   11/1/15 22:00               RAPE
# ...                   ...             ...             ...                ...
# 131291  201700000000000.0  11/14/17 23:30  11/14/17 23:53               RAPE
# 131294  201800000000000.0   11/15/17 0:00    1/18/18 0:00               RAPE
# 131353  201800000000000.0  11/15/17 12:00  11/15/17 18:00               RAPE
# 131419  201700000000000.0  11/15/17 19:00  11/15/17 19:30               RAPE
# 131445  201700000000000.0  11/15/17 21:00             NaN               RAPE
#
# ...
